# %%
import sys
import tensorflow as tf
import pandas as pd
import sklearn as sk
import numpy as np
import matplotlib


# from chat GPT 
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, optimizers

#----------------------------- from debajyotikarmaker sir lecture
import random
# from tqdm import tqdm ------------------ 🔴
import matplotlib.pyplot as plt

from datetime import datetime
import csv

# %%
# Define paths
dataset_path = "E:/CVPR/Dataset/ChestX-ray8"
categories = ['Atelectasis', 'Cardiomegaly', 'Effusion', 'Infiltrate', 'Mass', 'Nodule', 'Pneumonia', 'Pneumothorax']

# %%
# Define image dimensions
img_height, img_width = 224, 224
batch_size = 32

# Define data generators
datagen = ImageDataGenerator(validation_split=0.2, rescale=1./255)

# %%
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 790 images belonging to 8 classes.
# Found 194 images belonging to 8 classes.

# %%
# Create dummy bounding boxes
def add_dummy_bboxes(generator):
    while True:
        x, y_class = next(generator)
        y_bbox = np.random.rand(x.shape[0], 4)  # Random bounding boxes
        yield x, {'class_output': y_class, 'bbox_output': y_bbox}

train_generator_with_bboxes = add_dummy_bboxes(train_generator)
validation_generator_with_bboxes = add_dummy_bboxes(validation_generator)


# Define the model
input_shape = (img_height, img_width, 3)

inputs = tf.keras.Input(shape=input_shape)

# Feature extractor
x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)

# Classification head
class_output = layers.Dense(len(categories), activation='softmax', name='class_output')(x)

# Localization head (dummy implementation as dataset does not provide bounding boxes)
# Here, we'll generate random bounding boxes as placeholders.
bbox_output = layers.Dense(4, activation='sigmoid', name='bbox_output')(x)

# %%
# Combine into a model
model = tf.keras.Model(inputs=inputs, outputs=[class_output, bbox_output])

# Compile the model
model.compile(optimizer='adam',
              loss={'class_output': 'categorical_crossentropy', 'bbox_output': 'mse'},
              metrics={'class_output': 'accuracy', 'bbox_output': 'mse'})

# Train the model
history = model.fit(
    train_generator_with_bboxes,
    validation_data=validation_generator_with_bboxes,
    epochs=10,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_steps=validation_generator.samples // batch_size
)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 15s 594ms/step - loss: 2.5300 - class_output_loss: 2.4373 - bbox_output_loss: 0.0927 - class_output_accuracy: 0.1628 - bbox_output_mse: 0.0927 - val_loss: 2.1405 - val_class_output_loss: 2.0601 - val_bbox_output_loss: 0.0804 - val_class_output_accuracy: 0.1562 - val_bbox_output_mse: 0.0804
# Epoch 2/10
# 24/24 [==============================] - 11s 437ms/step - loss: 2.1323 - class_output_loss: 2.0465 - bbox_output_loss: 0.0858 - class_output_accuracy: 0.1794 - bbox_output_mse: 0.0858 - val_loss: 2.1326 - val_class_output_loss: 2.0449 - val_bbox_output_loss: 0.0877 - val_class_output_accuracy: 0.1927 - val_bbox_output_mse: 0.0877
# Epoch 3/10
# 24/24 [==============================] - 10s 438ms/step - loss: 2.0898 - class_output_loss: 2.0070 - bbox_output_loss: 0.0828 - class_output_accuracy: 0.2045 - bbox_output_mse: 0.0828 - val_loss: 2.1467 - val_class_output_loss: 2.0635 - val_bbox_output_loss: 0.0832 - val_class_output_accuracy: 0.1510 - val_bbox_output_mse: 0.0832
# Epoch 4/10
# 24/24 [==============================] - 10s 444ms/step - loss: 1.9740 - class_output_loss: 1.8892 - bbox_output_loss: 0.0849 - class_output_accuracy: 0.2731 - bbox_output_mse: 0.0849 - val_loss: 2.3477 - val_class_output_loss: 2.2543 - val_bbox_output_loss: 0.0934 - val_class_output_accuracy: 0.1979 - val_bbox_output_mse: 0.0934
# Epoch 5/10
# 24/24 [==============================] - 11s 453ms/step - loss: 1.8070 - class_output_loss: 1.7166 - bbox_output_loss: 0.0904 - class_output_accuracy: 0.3654 - bbox_output_mse: 0.0904 - val_loss: 2.4951 - val_class_output_loss: 2.4087 - val_bbox_output_loss: 0.0865 - val_class_output_accuracy: 0.2135 - val_bbox_output_mse: 0.0865
# Epoch 6/10
# 24/24 [==============================] - 10s 447ms/step - loss: 1.5767 - class_output_loss: 1.4852 - bbox_output_loss: 0.0915 - class_output_accuracy: 0.4512 - bbox_output_mse: 0.0915 - val_loss: 2.5990 - val_class_output_loss: 2.5069 - val_bbox_output_loss: 0.0921 - val_class_output_accuracy: 0.1979 - val_bbox_output_mse: 0.0921
# Epoch 7/10
# 24/24 [==============================] - 10s 447ms/step - loss: 1.2624 - class_output_loss: 1.1674 - bbox_output_loss: 0.0951 - class_output_accuracy: 0.5976 - bbox_output_mse: 0.0951 - val_loss: 3.0108 - val_class_output_loss: 2.9180 - val_bbox_output_loss: 0.0928 - val_class_output_accuracy: 0.1667 - val_bbox_output_mse: 0.0928
# Epoch 8/10
# 24/24 [==============================] - 11s 447ms/step - loss: 1.1395 - class_output_loss: 1.0417 - bbox_output_loss: 0.0978 - class_output_accuracy: 0.6293 - bbox_output_mse: 0.0978 - val_loss: 3.0493 - val_class_output_loss: 2.9551 - val_bbox_output_loss: 0.0942 - val_class_output_accuracy: 0.1458 - val_bbox_output_mse: 0.0942
# Epoch 9/10
# 24/24 [==============================] - 11s 451ms/step - loss: 0.9560 - class_output_loss: 0.8554 - bbox_output_loss: 0.1006 - class_output_accuracy: 0.7243 - bbox_output_mse: 0.1006 - val_loss: 3.1515 - val_class_output_loss: 3.0535 - val_bbox_output_loss: 0.0980 - val_class_output_accuracy: 0.1458 - val_bbox_output_mse: 0.0980
# Epoch 10/10
# 24/24 [==============================] - 10s 450ms/step - loss: 0.7939 - class_output_loss: 0.6896 - bbox_output_loss: 0.1043 - class_output_accuracy: 0.7929 - bbox_output_mse: 0.1043 - val_loss: 3.7510 - val_class_output_loss: 3.6483 - val_bbox_output_loss: 0.1027 - val_class_output_accuracy: 0.1719 - val_bbox_output_mse: 0.1027

# %%
# Evaluate the model

# loss, class_loss, bbox_loss, class_acc, bbox_mse = model.evaluate(validation_generator)
loss, class_loss, bbox_loss, class_acc, bbox_mse = model.evaluate(validation_generator_with_bboxes, steps=validation_generator.samples // batch_size)
print(f"Classification Accuracy: {class_acc:.4f}")
print(f"Localization MSE: {bbox_mse:.4f}")

# Predict and visualize the results for a few test samples
test_samples, test_labels = next(validation_generator)
pred_class, pred_bbox = model.predict(test_samples)
# Out:
# 6/6 [==============================] - 2s 320ms/step - loss: 3.7271 - class_output_loss: 3.6243 - bbox_output_loss: 0.1028 - class_output_accuracy: 0.1771 - bbox_output_mse: 0.1028
# Classification Accuracy: 0.1771
# Localization MSE: 0.1028
# 1/1 [==============================] - 0s 115ms/step

# %%
# Display some predictions
for i in range(10):
    plt.imshow(test_samples[i])
    plt.title(f"True Class: {categories[np.argmax(test_labels[i])]}, Pred Class: {categories[np.argmax(pred_class[i])]}")
    plt.xlabel(f"Pred BBox: {pred_bbox[i]}")
    plt.show()

# Plot the accuracy and loss graphs
plt.figure(figsize=(15,5))

# %%
# Plot training & validation accuracy values
plt.subplot(1,2,1)
plt.plot(history.history['class_output_accuracy'], 'o-', label='train accuracy')
plt.plot(history.history['val_class_output_accuracy'], 'o-', label='validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1,2,2)
plt.plot(history.history['loss'], 'o-', label='train loss')
plt.plot(history.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()
